# %%
print("HOPE AI")
print("----------------------------")
institute_name=input("Enter your institute name?")
if not institute_name:
  institute_name="HOPE AI"
print("Enter your institute name? : "+ institute_name)
print("----------------------------")

name=input("Enter your name?")
age=input("Enter your age?")
school_name=input("Enter your school name?")
degree=input("Enter your degree?")

if not name:
  name="Raj"

if not age:
  age="15"

if not school_name:
  school_name="Guru school"

if not degree:
  degree="B.E CSE"

print("Enter your name: "+ name)  #Raj
print("Enter your age: " + age) #15
print("Enter your school name: "+school_name) #Guru school
print("Enter your degree: "+ degree) #B.E CSE
print("----------------------------")

a=43
b=34
add=a+b
print("a= "+ str(a))
print("b= "+str(b))
print("add = "+str(add))

print("----------------------------")
sub=a-b
print("a= "+ str(a))
print("b= "+str(b))
print("Sub = "+str(sub))

print("----------------------------")

a= 63
b= 97
mul=a*b
print("a= "+ str(a))
print("b= "+str(b))
print("Mul = "+str(mul))

print("----------------------------")

a= 76
b= 31
div=a/b
print("a= "+ str(a))
print("b= "+str(b))
print("Float Div = "+str(div))

print("----------------------------")
div=a//b
print("a= "+ str(a))
print("b= "+str(b))
print("Floor Div = "+str(div))
print("----------------------------")

modulo=a%b
print("a= "+ str(a))
print("b= "+str(b))
print("Modulo = "+str(modulo))
print("----------------------------")

a= 4
b= 4
power = a**b
print("a= "+ str(a))
print("b= "+str(b))
print("Power = "+str(power))
# Out:
# HOPE AI
# ----------------------------
# Enter your institute name?
# Enter your institute name? : HOPE AI
# ----------------------------
# Enter your name?
# Enter your age?
# Enter your school name?
# Enter your degree?
# Enter your name: Raj
# Enter your age: 15
# Enter your school name: Guru school
# Enter your degree: B.E CSE
# ----------------------------
# a= 43
# b= 34
# add = 77
# ----------------------------
# a= 43
# b= 34
# Sub = 9
# ----------------------------
# a= 63
# b= 97
# Mul = 6111
# ----------------------------
# a= 76
# b= 31
# Float Div = 2.4516129032258065
# ----------------------------
# a= 76
# b= 31
# Floor Div = 2
# ----------------------------
# a= 76
# b= 31
# Modulo = 14
# ----------------------------
# a= 4
# b= 4
# Power = 256

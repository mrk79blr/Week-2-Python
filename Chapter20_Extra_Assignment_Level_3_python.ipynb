# %%
value=input("value=")
if not value:
  value="10"
if (int(value)==10):
  print ("Correct")

print("-----------------------")

pwd=input("Enter the password:")
if (pwd=="HOPE@123"):
  print("Your password is correct")
else:
  print("Your password is incorrect")

print("-----------------------")

age=input("Age?")

if not age:
  age=10
else:
  age=int(age)

if age < 13:
  print("Child")
elif age < 20:
  print("Teenager")
elif age < 60:
  print("Adult")
else:
  print("Senior Citizen")

print("-----------------------")

num=input("Enter any number:")

num=float(num)
if num>=0:
  print ("No is positive")
else:
  print ("No is negative")

print("-----------------------")

num=input("Enter any number to check whether it is divisible by 5 :")
num = float(num)
if num % 5 == 0:
    print(str(num)+" is divisible by 5")
else:
    print(str(num)+" is not divisible by 5")
# Out:
# value=
# Correct
# -----------------------
# Enter the password:
# Your password is incorrect
# -----------------------
# Age?
# Child
# -----------------------
# Enter any number:1
# No is positive
# -----------------------
# Enter any number to check whether it is divisible by 5 :5
# 5.0 is divisible by 5
